# %% [markdown]
# <a href="https://colab.research.google.com/github/FernandoRomeroZamora/Optativa-1/blob/main/series.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Llamar librerias

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Crear una serie

# %%
5 =
